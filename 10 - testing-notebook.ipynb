# %%
print(10)

# %%
print('Basha')

# %%
dbutils.widgets.text('fold_name', '', '')
dbutils.widgets.text('file_name', '', '')

# %%
fold_name = dbutils.widgets.get('fold_name')
file_name = dbutils.widgets.get('file_name')

# %%
df = spark.read.format('csv')\
  .option("header", "true")\
  .option("inferSchema", "true")\
  .load(fold_name+'/'+file_name)

display(df)
